# %% [markdown]
# ## بسم الله الرحمن الرحيم

# %% [markdown]
# ![image.png](attachment:8251b796-2381-4497-8af0-4d0afe15a4db.png)

# %% [markdown]
# ![image.png](attachment:68fdb104-456c-49df-8955-d635b9eed9e4.png)

# %%
import numpy as np

# %%
arr = np.array([
    [0.82, 0.78, 0.80],
    [0.91, 0.88, 0.90],
    [0.76, 0.81, 0.79],
    [0.88, 0.84, 0.86],
    [0.69, 0.72, 0.70]
])

# %%
arr
# Out:
# array([[0.82, 0.78, 0.8 ],
#        [0.91, 0.88, 0.9 ],
#        [0.76, 0.81, 0.79],
#        [0.88, 0.84, 0.86],
#        [0.69, 0.72, 0.7 ]])

# %%
len(arr) ## number of rows
# Out:
# 5

# %%
len(arr[0]) ## Number of element in first row
# Out:
# 3

# %%
arr.shape ## 5 represnets rows while the 3 is the columns
# Out:
# (5, 3)

# %%
arr.ndim ## Number of dimensions so this array is 2D array
# Out:
# 2

# %%
print("dtype:", arr.dtype) # This Represent the type of numbers in the array
# Out:
# dtype: float64

# %%
arr*=100

# %%
arr
# Out:
# array([[82., 78., 80.],
#        [91., 88., 90.],
#        [76., 81., 79.],
#        [88., 84., 86.],
#        [69., 72., 70.]])

# %% [markdown]
# ![image.png](attachment:5b0aa320-f4af-4aa1-9fa7-9a739b055483.png)

# %% [markdown]
# ![image.png](attachment:73780880-0987-4932-bf45-40c1e487c8ea.png)

# %%
arr[1,2] ## E2 Recall
# Out:
# np.float64(90.0)

# %%
arr[:,0] ## Accuracy Column
# Out:
# array([82., 91., 76., 88., 69.])

# %%
arr[:3,:2] ##First Three experiments with only accuracy and precision
# Out:
# array([[82., 78.],
#        [91., 88.],
#        [76., 81.]])

# %%
a = np.arange(24)
print(a.shape)     

b = a.reshape(4, 6)
print(b.shape)      

c = b.ravel()
print(c.shape)
# Out:
# (24,)
# (4, 6)
# (24,)

# %% [markdown]
# ![image.png](attachment:aefb6e60-ec2e-421f-bc83-f1ef9acf524b.png)

# %%
arr.mean()
# np.mean(arr)
# Out:
# np.float64(80.93333333333334)

# %%
arr.mean(axis=0) # if need for each row
# Out:
# array([81.2, 80.6, 81. ])

# %%
arr.mean(axis=1) ## each column
# Out:
# array([80.        , 89.66666667, 78.66666667, 86.        , 70.33333333])

# %%
np.std(arr) ## Standard Deviation
# Out:
# np.float64(6.826093725957442)

# %%
# np.var(arr)  variation
#### ORRRR
(np.std(arr)**2)
# Out:
# np.float64(46.59555555555555)

# %% [markdown]
# ![image.png](attachment:3643bcd0-ff61-4be3-9157-836eadcf3dfb.png)

# %%
new = arr[(arr[:, 0] >= 80) & (arr[:, 2] >= 80)]

# %%
print(new)
print(new.shape)
# Out:
# [[82. 78. 80.]
#  [91. 88. 90.]
#  [88. 84. 86.]]
# (3, 3)

# %%
new_exp = [85, 83, 87]

# %%
arr = np.vstack((arr, new_exp))

# %%
arr
# Out:
# array([[82., 78., 80.],
#        [91., 88., 90.],
#        [76., 81., 79.],
#        [88., 84., 86.],
#        [69., 72., 70.],
#        [85., 83., 87.]])

# %%
f1 = np.zeros((arr.shape[0], 1))

# %%
f1
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
arr = np.hstack((arr, f1))

# %%
arr
# Out:
# array([[82., 78., 80.,  0.],
#        [91., 88., 90.,  0.],
#        [76., 81., 79.,  0.],
#        [88., 84., 86.,  0.],
#        [69., 72., 70.,  0.],
#        [85., 83., 87.,  0.]])
